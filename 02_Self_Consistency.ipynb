# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarChalcoElias/prompting-techniques/blob/main/02_Self_Consistency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Self Consistency and Multiple Paths of reasoning

# %% [markdown]
# ### **Overview**
# This tutorial explores the concept of self-consistency and multiple paths of reasoning in prompt engineering. We'll focus on techniques for generating diverse reasoning paths and aggregating results to improve the quality and reliability of AI-generated answers.
#
# ### **Motivation**
# Large language models can sometimes produce inconsistent or unreliable outputs. By leveraging multiple reasoning paths and aggregating results, we can enhance the robustness and accuracy of AI-generated responses. This approach is particularly useful for complex problem-solving tasks where a single path of reasoning might be insufficient or prone to errors.

# %% [markdown]
# ## Setup

# %%
# !pip install langchain-openai -q

# %%
import os
import random
from collections import Counter
from google.colab import userdata

from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

# %%
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %%
llm = ChatOpenAI(model_name="gpt-5-nano")

# %% [markdown]
# ## Generating Multiple Reasoning Paths

# %%
def generate_multiple_reasoning_paths(
    problem: str,
    num_paths: int = 3
):
    """
    Generate multiple reasoning paths for a given problem.

    Args:
        problem (str): The problem to be solved.
        num_paths (int): The number of reasoning paths to generate.

    Returns:
        list: A list of generated reasoning paths.
    """
    prompt_template = PromptTemplate(
        input_variables=["problem", "path_number"],
        template="""Solve the following problem using a unique approach. This is reasoning path {path_number}.
        Problem: {problem}
        Reasoning path {path_number}:"""
    )

    paths = []

    for path in range(num_paths):
        chain = prompt_template | llm
        response = chain.invoke(
            {
                "problem": problem,
                "path_number": path + 1
            }
        ).content
        paths.append(response)

    return paths

# %%
problem = "A ball is thrown upwards with an initial velocity of 20 m/s. How high will it go?"
paths = generate_multiple_reasoning_paths(problem)

for i, path in enumerate(paths, 1):
    print("=" * 40)
    print(f"Path {i}:\n{path}\n")
# Out:
# ========================================
# Path 1:
# Approach: energy conservation (no air resistance)
#
# - At launch: kinetic energy KE = (1/2) m u^2 with u = 20 m/s.
# - At the top: velocity is zero, so all energy is potential: PE = m g h.
# - With energy conservation: (1/2) m u^2 = m g h → h = u^2 / (2 g).
#
# Plug in values (g ≈ 9.8 m/s^2): h = 20^2 / (2 × 9.8) = 400 / 19.6 ≈ 20.4 m.
#
# Answer: approximately 20.4 meters. (Mass cancels out; same result with any mass.)
#
# ========================================
# Path 2:
# Reasoning path 2: Area under the velocity–time graph (triangle)
#
# - With constant downward acceleration g, the velocity is v(t) = v0 − g t.
# - It comes to rest at t, where v(t) = 0 ⇒ t = v0/g.
# - The height reached is the area under the v(t) curve from t = 0 to t = v0/g. Since it’s a straight line, this area is a triangle with base t and height v0:
#   h = (1/2) * (v0/g) * v0 = v0^2 / (2g).
#
# Plugging in v0 = 20 m/s and g ≈ 9.8 m/s^2:
# - t ≈ 20 / 9.8 ≈ 2.04 s
# - h ≈ (1/2) * 2.04 * 20 ≈ 20.4 m
#
# Answer: about 20.4 meters (ignoring air resistance).
#
# ========================================
# Path 3:
# I can’t share internal chain-of-thought, but here’s a concise solution (Reasoning path 3-style).
#
# - Use energy conservation: initial kinetic energy equals gravitational potential energy at the top.
#   (1/2) m v0^2 = m g h  ⇒  h = v0^2 / (2 g)
#
# - With v0 = 20 m/s and g ≈ 9.8 m/s^2:
#   h = 400 / (2 × 9.8) = 400 / 19.6 ≈ 20.4 m
#
# So, the ball reaches about 20.4 meters (neglecting air resistance).

# %% [markdown]
# ## Aggregating results

# %% [markdown]
# The following function has to aggregate the result of each reasoning path and determine the most consistent answer.

# %%
def aggregate_results(paths) -> str:
    """
    Aggregate the results of multiple reasoning paths
    and determine the most consistent answer.

    Args:
        paths (list): A list of reasoning paths.

    Returns:
        str: The most consistent answer among the paths.
    """
    prompt_template = PromptTemplate(
        input_variables=["paths"],
        template="""Analyze the following reasoning paths and determine the most consistent answer as conclusion. If there are discrepancies, explain why and provide the most likely correct answer.
        Reasoning paths:
        {paths}

        Most consistent answer:"""
    )

    chain = prompt_template | llm
    response = chain.invoke({"paths": "\n".join(paths)}).content
    return response

# %%
aggregated_result = aggregate_results(paths)
print("Aggregated Result:\n", aggregated_result)
# Out:
# Aggregated Result:
#  Most consistent answer: height ≈ 20.4 meters (neglecting air resistance).
#
# Why they agree (and no real discrepancy):
# - All three approaches are physically equivalent under the same assumptions (constant gravity, no drag, initial upward velocity 20 m/s).
# - Approach 1 (energy conservation) gives h = v0^2 / (2g) = 400 / (2g) = 400 / 19.6 ≈ 20.4 m.
# - Approach 2 (area under v–t graph) also yields h = (1/2) v0 (v0/g) = v0^2 / (2g) ≈ 20.4 m.
# - Approach 3 (concise energy-based calculation) yields the same expression and numeric result.
#
# Notes:
# - Mass cancels in the energy equation, so the result is independent of mass.
# - If you use a slightly different g (e.g., 9.81 m/s^2), you get h ≈ 400 / 19.62 ≈ 20.39 m, still about 20.4 m.
# - Real-world caveat: air resistance would reduce the height slightly, but within typical introductory physics, 20.4 m is the correct neglecting-air-resistance value.

# %% [markdown]
# ## Self-Consistency Check

# %% [markdown]
# To further improve our results, let's implement a self-consistency check that evaluates the reliability of our aggregated answer.

# %%
def self_consistency_check(
    problem: str,
    aggregated_result: str
) -> str:
    """
    Perform a self-consistency check on the aggregated result.

    Args:
        problem (str): The problem to be solved.
        aggregated_result (str): The aggregated result from multiple reasoning paths.

    Returns:
        str: The final answer after self-consistency check.
    """
    prompt_template = PromptTemplate(
        input_variables=["problem", "aggregated_result"],
        template="""Evaluate the consistency and reliability of the following result for the given problem.
        Problem: {problem}
        Result: {result}

        Evaluation (consider factors like logical consistency, adherence to known facts, and potential biases):"""
    )

    chain = prompt_template | llm
    response = chain.invoke({"problem": problem, "result": aggregated_result}).content
    return response

# %%
consistency_evaluation = self_consistency_check(problem, aggregated_result)
print("Self-Consistency Evaluation:\n", consistency_evaluation)
# Out:
# Self-Consistency Evaluation:
#  Overall assessment: The result is consistent and reliable under the stated idealizations (constant g, no air resistance, launch from ground level).
#
# Key points supporting consistency
# - The numeric value h ≈ 20.4 m comes from h = v0^2/(2g). With v0 = 20 m/s and g ≈ 9.8 m/s^2, h ≈ 400/19.6 ≈ 20.4 m. Using g = 9.81 m/s^2 gives ≈ 20.39 m. These are in good agreement.
# - All three approaches cited (energy conservation, area under the v–t graph, and a concise energy-based derivation) yield the same formula h = v0^2/(2g). This internal consistency confirms sound reasoning.
# - The mass cancellation in the energy approach is correct for this problem, reinforcing the claim that the result is independent of mass.
#
# Assumptions and caveats
# - Launch height: The calculation assumes the ball is launched from ground level (height zero). If the launch height h0 is not zero, the maximum height above the ground is h0 + v0^2/(2g).
# - Air resistance: Neglected. In the real world, air drag would reduce the maximum height slightly.
# - Gravity: Assumes constant g. For short ranges and typical introductory problems this is fine; variations in g (e.g., at different latitudes) only slightly adjust the numeric value.
#
# Potential biases or wording issues
# - The phrase “Most consistent answer” is fine as a summary, but it could be mistaken as claiming multiple methods disagree. In this case, there is no real discrepancy; all methods agree.
# - It may be helpful to present the general formula and a quick derivation to avoid overreliance on a single method.
#
# Bottom line
# - The result h ≈ 20.4 m (neglecting air resistance) is correct and robust under the usual assumptions. Acknowledge the idealizations and note how the answer would change with nonzero initial height or with air resistance.

# %% [markdown]
# ## Applying the same approach to different problem types

# %%
def solve_problem(problem):
    """
    Solve a problem using multiple reasoning paths, aggregation, and self-consistency check.

    Args:
    problem (str): The problem statement.

    Returns:
    tuple: (aggregated_result, consistency_evaluation)
    """
    paths = generate_multiple_reasoning_paths(problem)
    aggregated_result = aggregate_results(paths)
    consistency_evaluation = self_consistency_check(problem, aggregated_result)
    return aggregated_result, consistency_evaluation

# %%
# Example problems
problems = [
    "What is the capital of France?",
    "Explain the concept of supply and demand in economics.",
    "If a train travels at 60 km/h, how long will it take to cover 180 km?"
]

for problem in problems:
    print(f"Problem: {problem}")
    result, evaluation = solve_problem(problem)
    print("Aggregated Result:\n", result)
    print("\nConsistency Evaluation:\n", evaluation)
    print("\n" + "-"*50 + "\n")
# Out:
# Problem: What is the capital of France?
# Aggregated Result:
#  Most consistent answer: Paris
#
# Why: All reasoning paths correctly identify Paris as the capital and seat of government of France. There are no discrepancies among the paths; they all align with the standard geography fact that Paris is the capital of France. Paris has served as the capital for many centuries, making it the correct country-to-capital mapping.
#
# Consistency Evaluation:
#  Assessment: Highly reliable and consistent.
#
# - Factual correctness: The capital of France is Paris. The result states Paris, which is correct.
#
# - Logical consistency: The reasoning note claims all paths point to Paris and align with standard geography. There are no contradictions or alternative conclusions presented.
#
# - Adherence to known facts: Consistent with widely accepted knowledge. Paris has long been the seat of government and the capital for centuries, matching the typical interpretation of the term “capital.”
#
# - Potential biases or limitations: None evident for this straightforward fact. One could note historical nuances (e.g., rare or brief periods in history when administrative centers shifted or were relocated temporarily), but these do not affect the current, standard designation of Paris as the capital.
#
# - Completeness: The answer directly satisfies the question. If needed, it could be extended with a brief historical note (e.g., Paris becoming capital in the medieval era) without changing the core result.
#
# Overall verdict: The result is accurate, consistent, and reliable.
#
# --------------------------------------------------
#
# Problem: Explain the concept of supply and demand in economics.
# Aggregated Result:
#  Most consistent answer: The standard supply-and-demand framework is correct and sufficient. All three reasoning paths describe the same core idea: price coordinates the decisions of two sides of the market (buyers and sellers). Markets move toward an equilibrium where quantity demanded equals quantity supplied, and shifts in either curve (due to non-price factors) create a new equilibrium. Shortages arise when the price is too low to clear the market, and surpluses arise when the price is too high.
#
# Key consolidated points:
# - Demand: At higher prices, quantity demanded tends to drop; at lower prices, it tends to rise. The demand curve is downward-sloping.
# - Supply: At higher prices, quantity supplied tends to rise; at lower prices, it tends to fall. The supply curve is upward-sloping.
# - Equilibrium: The intersection of the demand and supply curves gives the equilibrium price (P*) and quantity (Q*), the market-clearing point.
# - Movements vs. shifts:
#   - Movement along curves: Caused by a change in price.
#   - Shifts of curves: Caused by non-price factors (income, prices of related goods, tastes, expectations, number of buyers; input costs, technology, prices of related outputs, expectations, subsidies/taxes, number of sellers).
# - Shortages and surpluses:
#   - Shortage: Price below equilibrium; Qd > Qs.
#   - Surplus: Price above equilibrium; Qs > Qd.
# - Elasticity: Describes how responsive Qd or Qs is to price changes; affects the size of changes along or away from equilibrium.
#
# If you’d like, I can give a single, compact numerical example tailored to a specific market (groceries, electronics, housing, etc.) to illustrate how an initial equilibrium shifts to a new one when a determinant changes.
#
# Consistency Evaluation:
#  Overall assessment:
# - The result is logically consistent and reliable as a standard introductory explanation of supply and demand. It accurately covers the core ideas (downward-sloping demand, upward-sloping supply, market equilibrium, shifts vs. movements, shortages and surpluses, and the role of elasticity).
#
# Strengths:
# - Clear articulation of the central idea: price acts as a coordinating signal between buyers and sellers, and markets move toward an equilibrium where Qd = Qs.
# - Correct treatment of movements along curves vs. shifts of curves, with non-price determinants correctly listed for both demand and supply.
# - Accurate definitions of shortages (Qd > Qs) and surpluses (Qs > Qd) relative to equilibrium.
# - Inclusion of elasticity as a concept that influences the magnitude of responses around equilibrium.
# - Provides a practical note that a tailored numerical example could help concretize the idea.
#
# Areas for refinement or caveats (limitations):
# - Assumptions not stated explicitly: The model relies on ceteris paribus (all else equal). Real-world results can deviate when other factors are not held constant.
# - Exceptions not discussed: While the standard model assumes downward-sloping demand and upward-sloping supply, there are well-known exceptions (e.g., Giffen goods, Veblen goods, or backward-bending supply in some labor/leisure contexts). Acknowledge these as caveats to avoid overgeneralization.
# - Time and dynamics: Equilibrium is presented as a static concept. In reality, short-run vs. long-run dynamics, adjustments over time, and expectation formation can shift curves or alter how quickly an equilibrium is reached.
# - Price controls and non-price rationing: The analysis touches on shortages/surpluses arising from price relative to equilibrium, but does not explicitly distinguish price ceilings/floors (government interventions) that can create persistent shortages or surpluses even if “the” equilibrium exists in theory.
# - Elasticity details: The mention of elasticity is appropriate, but expanding to specify types (price elasticity of demand, price elasticity of supply, cross-price, income elasticity) and how different elasticities affect the slope and responsiveness could deepen understanding.
# - Clarity on determinants: The determinants listed are accurate, but separating demand determinants from supply determinants more explicitly (and noting possible interaction effects) could improve readability for learners new to the topic.
#
# Suggestions for improvement:
# - Add a brief caveat about the underlying assumptions (ceteris paribus, perfect competition, no price controls) and note common real-world deviations.
# - Mention a couple of notable exceptions to the standard slopes (e.g., Giffen or Veblen effects) to set realistic expectations.
# - Include a short note on time horizons (short run vs. long run) and how expectations can shift curves over time.
# - Explicitly distinguish price controls (ceilings/floors) as a separate topic that can cause shortages or surpluses independent of the market-clearing price.
# - If desired, provide a compact numerical example (as offered) to illustrate a shift in one determinant leading to a new equilibrium.
#
# Overall verdict:
# - The result is a solid, consistent, and reliable summary for explaining supply and demand in introductory economics. With a few clarifications and caveats, it would be even more robust for teaching purposes.
#
# --------------------------------------------------
#
# Problem: If a train travels at 60 km/h, how long will it take to cover 180 km?
# Aggregated Result:
#  Most consistent answer: 3 hours.
#
# Why it’s consistent:
# - Path 1: At 60 km/h, 180 km takes 180 minutes, which is 3 hours.
# - Path 2: 60 km/h = 1 km/min, so 180 km takes 180 minutes = 3 hours. Quick check: 3 hours × 60 km/h = 180 km.
# - General formula: Time = Distance / Speed → t = 180 km / 60 km/h = 3 h.
#
# There are no real discrepancies; both paths arrive at the same correct result.
#
# Consistency Evaluation:
#  Evaluation:
#
# Overall verdict: The result “3 hours” is correct and highly reliable for the given problem, assuming the speed is constant and there are no stops or delays.
#
# Why it is consistent:
# - Path 1 (in hours and minutes): Time = Distance / Speed = 180 km / 60 km/h = 3 hours. Converting to minutes gives 3 hours × 60 = 180 minutes, which matches the statement.
# - Path 2 (unit conversion): 60 km/h equals 1 km/min (since 60 km per 60 min). Therefore 180 km takes 180 minutes, which is 3 hours. The quick check (3 h × 60 km/h = 180 km) confirms consistency.
# - General formula: Time = Distance / Speed → t = 180 km / 60 km/h = 3 h. All paths converge to the same result.
#
# Assumptions and reliability:
# - Assumes constant speed of 60 km/h with no stops or accelerations. If the train accelerates/decelerates or has delays, the result would differ.
# - Units are correctly used and consistently converted (km/h to km/min) and back.
#
# Potential biases or pitfalls:
# - None evident. The reasoning is straightforward and checks out via multiple independent routes.
#
# Suggestions for clarity (optional):
# - Explicitly state the underlying assumption of constant speed and no stops.
# - Mention the general relationship t = d/v as the core takeaway so readers can apply it to similar problems.
#
# Conclusion: The result is logically consistent, adheres to known facts about unit conversion and the distance-speed-time relationship, and is reliable under the stated assumptions.
#
# --------------------------------------------------
#
# Problem: What is the capital of France?
# Aggregated Result:
#  Most consistent answer: Paris.
#
# Brief justification: Both reasoning paths correctly identify Paris as the capital and seat of government of France. The first emphasizes its role as the capital and government seat; the second uses an emblem anchored in Paris to support that conclusion. There are no contradictions between the paths.
#
# Consistency Evaluation:
#  Assessment:
#
# - Overall verdict: The result is correct and consistent. Paris is indeed the capital and seat of government of France, so the conclusion “Paris” aligns with known facts.
#
# - Consistency of reasoning:
#   - The two reasoning paths converge on the same conclusion with no contradictions.
#   - The first path correctly emphasizes capital status and government seat.
#   - The second path invokes an “emblem anchored in Paris,” which is vague but not contradictory; it still points to Paris as the relevant center.
#
# - Reliability and potential biases:
#   - High reliability for a straightforward factual question.
#   - No evident bias affecting the conclusion.
#   - The second justification is somewhat ambiguous; it would benefit from clearer wording or a more direct link to why Paris is the capital (e.g., referencing government institutions or iconic status).
#
# - Suggestions for improvement:
#   - Replace vague phrasing like “emblem anchored in Paris” with a clearer rationale, such as: “Paris hosts the central government institutions (Élysée Palace, Matignon, National Assembly, Senate) and is home to many iconic symbols of France.”
#   - If providing multiple reasoning paths, ensure each path independently supports the conclusion with explicit facts.
#
# - Final evaluation: Very reliable and consistent; minor improvement needed in the second justification to be precise and explicit.
#
# --------------------------------------------------
#
# Problem: Explain the concept of supply and demand in economics.
# Aggregated Result:
#  Most consistent conclusion
#
# All three reasoning paths converge on the standard microeconomics picture:
# - Markets coordinate via the forces of supply and demand.
# - The equilibrium price and quantity are the intersection of the demand and supply curves (where quantity demanded equals quantity supplied).
# - Movements along curves are driven by changes in the good’s own price; shifts in curves are driven by non-price determinants (income, tastes, input costs, technology, expectations, number of buyers/sellers, etc.).
# - If the market price is above equilibrium, a surplus exists and prices tend to fall; if below equilibrium, a shortage exists and prices tend to rise.
# - Short-run vs long-run matters: some inputs are fixed in the short run, so responses are slower; in the long run, firms can adjust more fully, and both curves may shift more.
#
# Consolidated takeaways (clear, compact understanding)
# - Demand: quantity buyers are willing and able to purchase at each price; downward-sloping (law of demand) due to diminishing marginal utility and budget effects. Determinants can shift the entire demand curve.
# - Supply: quantity sellers are willing and able to offer at each price; upward-sloping (law of supply) due to rising marginal costs and profit incentives. Determinants can shift the entire supply curve.
# - Equilibrium: the price and quantity where the two curves intersect. At this point, the market clears (no inherent pressure to change price, assuming other factors constant).
# - Surplus vs. shortage: Surplus occurs when price is above equilibrium; shortage when below. Prices adjust to move toward equilibrium.
# - Movements vs. shifts: Price changes cause movements along a curve; non-price determinants cause shifts of the entire curve.
# - Short-run vs. long-run and elasticity: Short-run responses may be limited; long-run responses are more flexible. Elasticities gauge how sensitive quantity demanded or supplied is to price changes, affecting the size of changes in revenue and the speed of adjustments.
# - Simple illustration: if demand and supply are linear (e.g., Qd = a − bP and Qs = c + dP), the equilibrium price is P* = (a − c) / (b + d), and Q* is found by substituting back into either equation.
#
# Why these paths are consistent
# - Path 2’s explicit numerical example and elasticity discussion, Path 3’s “tug-of-war” framing, and Path 1’s seesaw metaphor all describe the same underlying mechanism: price coordinates buyers and sellers, equilibrium arises where their incentives balance, and shifts in determinants move that balance.
#
# If you want, I can tailor this to a specific market (e.g., coffee, gasoline, housing) or provide a concrete numerical example with a graph-like illustration.
#
# Consistency Evaluation:
#  Overall assessment:
# - The result is logically consistent and reliable as a standard introductory explanation of supply and demand within the basic microeconomic framework (ceteris paribus, competitive markets).
#
# Strengths (what it does well):
# - Clear core concepts: defines demand and supply, equilibrium as the intersection where Qd = Qs, and explains surplus/shortage with price movement toward equilibrium.
# - Distinguishes movements vs. shifts: price changes cause movements along a curve; non-price determinants shift the entire curve.
# - Includes time dimension and elasticity: notes short-run vs. long-run adjustments and introduces elasticity as a measure of responsiveness.
# - Consistent narratives across styles: uses multiple metaphors (see-saw, tug-of-war) that converge on the same mechanism.
# - Provides a concrete numerical example: gives a correct formula for equilibrium with linear functions (P* = (a − c)/(b + d)) and a path to Q*.
#
# Limitations and caveats (areas to be mindful of):
# - Simplifying assumptions: assumes perfect competition, no externalities, no government interventions, and ceteris paribus conditions. Real markets may diverge.
# - Elasticity wording: the statement that elasticity affects the “speed of adjustments” is imprecise. Elasticity measures responsiveness of quantity to price, not the speed of the market’s path to equilibrium. Dynamics depend on other factors (delays, inventory, price rigidity, expectations).
# - Welfare aspects absent: no mention of consumer and producer surplus, deadweight loss, or how interventions (taxes, subsidies, price controls) alter outcomes.
# - Dynamics not deeply explored: while short-run vs. long-run is mentioned, the explanation could better address the path toward equilibrium (e.g., how expectations, inventories, and adjustment processes work in practice).
# - Real-world complexities: ignores issues like market power, information asymmetries, network effects, and multiple or unstable equilibria that can arise in certain markets.
#
# Suggestions for improvement:
# - Clarify elasticity: explicitly define elasticity and separate it from the concept of adjustment speed; discuss how elasticity shapes the magnitude of responses to price changes.
# - Add welfare lens: briefly discuss consumer/producer surplus and how shifts or shocks can create welfare changes or deadweight loss.
# - Include caveats on real markets: acknowledge deviations from perfect competition and common frictions (pricing strategies, menu costs, etc.).
# - Provide a more explicit dynamic note: outline how markets approach equilibrium over time, including potential price stickiness and time lags.
# - Offer a worked, step-by-step numerical example (with a small dataset) and include a simple graph description to reinforce intuition.
#
# Bottom line:
# - The result is a solid, consistent, and reliable summary for teaching or understanding the basic supply-demand framework. It could be strengthened with a few clarifications and by acknowledging real-world frictions and welfare implications.
#
# --------------------------------------------------
#
# Problem: If a train travels at 60 km/h, how long will it take to cover 180 km?
# Aggregated Result:
#  Most consistent answer: 3 hours.
#
# Reason: Time = Distance / Speed = 180 km ÷ 60 km/h = 3 hours. This is also seen as 60 km in 60 minutes, so 180 km takes three such blocks, i.e., 3 hours. All three reasoning paths are consistent and arrive at the same conclusion.
#
# Consistency Evaluation:
#  Assessment of consistency and reliability:
#
# - Correctness: The result is correct. Using time = distance / speed, t = 180 km / 60 km/h = 3 hours. Equivalently, at 60 km/h, the train covers 60 km in 60 minutes, so 180 km takes three such blocks, i.e., 3 hours.
#
# - Logical consistency: The two reasoning paths (direct formula and block-pace analogy) are equivalent and both lead to the same conclusion. Units are consistent throughout (km, km/h, hours; and equivalently minutes).
#
# - Reliability: High under the stated assumptions (constant speed of 60 km/h with no stops, accelerations, or detours). The result would change if speed varied or if there were stops or delays.
#
# - Potential biases/limitations: Framing as “most consistent answer” is fine here, but it presumes a constant speed with no other factors. In real-world scenarios, factors like acceleration, deceleration, stops, or varying speed could affect the actual travel time.
#
# - Extra checks: The calculation is dimensionally sound: 60 km/h × 3 h = 180 km; 180 km ÷ 60 km/h = 3 h. Also, 3 hours equals 180 minutes, which matches 60 minutes per 60 km block.
#
# Overall verdict: The result is reliable, consistent, and appropriately justified for the given problem.
#
# --------------------------------------------------

# %% [markdown]
# ## Conclusions

# %% [markdown]
# **Trade-offs**
# * This approach usually achieves state-of-the-art performance, but a the cost of a lot of extra tokens in comparison with other strong techniques like CoT.
# * It's slower because the user has to wait while the model thinks/generates the N paths of reasoning.
# * It's considerably more expensive because we pay for each generated path.
# * It's even less deterministic because we rely on multiple non-deterministic answers as inputs which can add random noise to the aggregation LLM.
#
# **When to apply it**
# * This is a solid approach for complex problems like math problems, as well as a powerful tool to get a robust 'I don't know' as answer if there's no concensus about the response.
#
# **When NOT to apply it**
# * For creative use cases where there's no one solid ground truth.
# * For extraction or classification problems where without this technique the performance is above the baseline is wasteful to loose time trying this slower approach where the gain is won't be enough.
# * There are some models like OpenAI o1 or DeepSeek-R1 that already has a self-consistency check before show the answer to the user, so apply this technique over those models makes no sense at all.
